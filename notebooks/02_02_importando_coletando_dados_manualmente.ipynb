# %% [markdown]
# # Importando e coletando dados manualmente
#
# Aprenda a consumir dados importando a partir de aquivo do tipo csv.

# %%
import pandas as pd

# %%
transfusoes = pd.read_csv('/content/02_02_importando_e_coletando_dados_manualmente.csv', sep=';', encoding='latin1', skiprows=4)

# %%
transfusoes.head()
# Out:
#    Ano: 2023  Número de transfusões (bolsas utilizadas) de hemocomponentes    \
# 0    JANEIRO                                              353.0
# 1  FEVEREIRO                                              415.0
# 2      MARÇO                                              451.0
# 3      ABRIL                                              455.0
# 4       MAIO                                              425.0
#
#    Concentrado de Hemácias (CH)  \
# 0                          22.0
# 1                          10.0
# 2                          22.0
# 3                           9.0
# 4                          41.0
#
#    Concentrado de Hemácias Pobre em Leucócitos (CHPL)  \
# 0                                               84.0
# 1                                              115.0
# 2                                              116.0
# 3                                              158.0
# 4                                              132.0
#
# ...
