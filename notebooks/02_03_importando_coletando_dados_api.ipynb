# %% [markdown]
# # Importando e coletando dados usando API
#
# Aprenda a consumir dados através do uso de API.

# %%
import requests
import pandas as pd

# %%
indicador = requests.get('https://servicodados.ibge.gov.br/api/v1/paises/BR/indicadores/77830').json()

# %%
indicador
# Out:
# [{'id': 77830,
#   'indicador': 'Indicadores sociais - Esperança de vida ao nascer',
#   'unidade': {'id': 'anos', 'classe': 'N', 'multiplicador': 1},
#   'series': [{'pais': {'id': 'BR', 'nome': 'Brasil'},
#     'serie': [{'-': None},
#      {'1990': None},
#      {'1990-1995': None},
#      {'1995': None},
#      {'1995-2000': None},
#      {'1999-2001': None},
#      {'2000': '69.737'},
#      {'2000-2002': None},
#      {'2000-2005': None},
#      {'2001': '70.195'},
#      {'2001-2003': None},
#      {'2002': '70.41'},
#      {'2002-2004': None},
#      {'2003': '70.72'},
#      {'2003-2005': None},
#      {'2004': '71.131'},
#      {'2004-2006': None},
#      {'2005': '71.753'},
#      {'2005-2007': None},
#      {'2005-2010': None},
#      {'2006': '72.037'},
#      {'2006-2008': None},
#      {'2007': '72.365'},
#      {'2007-2009': None},
#      {'2008': '72.715'},
#      {'2008-2010': None},
#      {'2009': '72.948'},
#      {'2009-2011': None},
#      {'2010': '73.182'},
# ...

# %%
df_indicador = pd.DataFrame.from_dict(indicador[0]['series'][0]['serie'])

# %%
df_indicador.head()
# Out:
#     -  1990  1990-1995  1995  1995-2000  1999-2001 2000  2000-2002  2000-2005  \
# 0 NaN   NaN        NaN   NaN        NaN        NaN  NaN        NaN        NaN
# 1 NaN   NaN        NaN   NaN        NaN        NaN  NaN        NaN        NaN
# 2 NaN   NaN        NaN   NaN        NaN        NaN  NaN        NaN        NaN
# 3 NaN   NaN        NaN   NaN        NaN        NaN  NaN        NaN        NaN
# 4 NaN   NaN        NaN   NaN        NaN        NaN  NaN        NaN        NaN
#
#   2001  ...  2018-2020 2019  2019-2021 2020  2020-2022 2021  2021-2023 2022  \
# 0  NaN  ...        NaN  NaN        NaN  NaN        NaN  NaN        NaN  NaN
# 1  NaN  ...        NaN  NaN        NaN  NaN        NaN  NaN        NaN  NaN
# 2  NaN  ...        NaN  NaN        NaN  NaN        NaN  NaN        NaN  NaN
# 3  NaN  ...        NaN  NaN        NaN  NaN        NaN  NaN        NaN  NaN
# 4  NaN  ...        NaN  NaN        NaN  NaN        NaN  NaN        NaN  NaN
#
#    2022-2024  2023
# 0        NaN   NaN
# ...

# %%
df_limpo = df_indicador.dropna(axis=1, how='all')

# %%
for col in df_limpo.columns:
    df_limpo[col] = pd.to_numeric(df_limpo[col], errors='coerce')
# Out:
# /tmp/ipython-input-3474855476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpo[col] = pd.to_numeric(df_limpo[col], errors='coerce')

# %%
mask_tem_valores = df_limpo.notna().any(axis=0)

# %%
df_final = df_limpo.loc[:, mask_tem_valores]

# %%
df_final.sample(10)
# Out:
#     2000  2001  2002  2003  2004    2005  2006  2007  2008  2009  ...    2013  \
# 48   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 0    NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 17   NaN   NaN   NaN   NaN   NaN  71.753   NaN   NaN   NaN   NaN  ...     NaN
# 38   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 25   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 35   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...  73.918
# 23   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 19   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 21   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
# 8    NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  ...     NaN
#
#     2014  2015  2016  2017  2018    2019  2020  2021  2022
# ...

# %%
# Coletar todos os valores não nulos de todas as colunas
valores_reais = []
nomes_colunas = []

for coluna in df_final.columns:
    valores_nao_nulos = df_final[coluna].dropna()
    for valor in valores_nao_nulos:
        valores_reais.append(valor)
        nomes_colunas.append(f"{coluna}_{len([x for x in valores_reais if str(x).startswith(str(coluna))])}")

# Criar dataframe com uma única linha
df_uma_linha = pd.DataFrame([valores_reais], columns=nomes_colunas)

# %%
df_final.head()
# Out:
#    2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  ...  2013  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 23 columns]
